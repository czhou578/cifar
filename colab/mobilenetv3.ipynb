# %% [markdown]
# Depthwise separable convolutions are defined by
# two separate layers: light weight depthwise convolution for
# spatial filtering and heavier 1x1 pointwise convolutions for
# feature generation (setting groups in pytorch)!
#
# use swish nonlinearity: h-swish[x] = x * ReLU6(x + 3) / 6
#
# each layer activation memory typically halves every time the resolution drops. Incidentally, we find that most of the benefits swish are realized by using them only in the deeper layers.
#
# Bneck block:
#
# expansion layer (1x1 conv) + swish
# depthwise conv + swish
# squeeze and excitation: global avg pooling, two fully connected layers with swish in between, sigmoid at the end, scale the input to the depthwise conv
# projection layer (1x1 conv)
#
# https://medium.com/data-science/a-basic-introduction-to-separable-convolutions-b99ec3102728
#
# Mistakes: Padding should be kernel_size // 2, not hardcoded 3

# %%
import torch
from torch import nn
from torchvision import transforms, datasets
from torch.utils.data import DataLoader, Subset

class BottleneckBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, reduction_factor, exp_factor, stride, isSwish):
        super().__init__()

        self.isSwish = isSwish
        self.use_skip = (in_channels == out_channels and stride == 1)

        expanded_channels = int(in_channels * exp_factor)

        self.expansion_layer = nn.Sequential(
            nn.Conv2d(in_channels, expanded_channels, kernel_size=1, stride = 1),
            nn.BatchNorm2d(expanded_channels),
        )

        self.global_avg_pool = nn.AdaptiveAvgPool2d((1, 1))

        self.depthwise_conv = nn.Sequential(
            nn.Conv2d(expanded_channels, expanded_channels, kernel_size, padding=kernel_size // 2, groups=expanded_channels, stride=stride),
            nn.BatchNorm2d(expanded_channels)            
        )

        self.excitation_layers = nn.Sequential(
            nn.Linear(expanded_channels, expanded_channels // reduction_factor),
            nn.SiLU(),
            nn.Linear(expanded_channels // reduction_factor, expanded_channels),
        )

        self.projection_layer = nn.Sequential(
            nn.Conv2d(expanded_channels, out_channels, kernel_size=1, stride=1),
            nn.BatchNorm2d(out_channels)
        )

    def hard_sigmoid(self, x):
        return nn.functional.relu6(x + 3) / 6

    def swish(self, x):
        return x * nn.functional.sigmoid(x)

    def relu(self, x):
        return nn.functional.relu(x)

    def forward(self, x):
        # Expansion + activation
        features = self.expansion_layer(x)
        features = self.swish(features) if self.isSwish else self.relu(features)
        
        # Depthwise + activation
        features = self.depthwise_conv(features)
        features = self.swish(features) if self.isSwish else self.relu(features)
        
        # SE module
        pooled = self.global_avg_pool(features)
        squeezed = pooled.squeeze(-1).squeeze(-1)
        excitation = self.excitation_layers(squeezed)
        excitation = torch.sigmoid(excitation)  # Use sigmoid, not hard_sigmoid
        excitation = excitation.unsqueeze(-1).unsqueeze(-1)
        features = features * excitation
        
        # Projection (no activation)
        features = self.projection_layer(features)
        
        return features + x if self.use_skip else features

class MobileNetV3(nn.Module):
    def __init__(self):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Conv2d(3, 16, stride=2, kernel_size=3, padding=1),
            BottleneckBlock(16, 16, 3, 4, 1, 1, False),
            BottleneckBlock(16, 24, 3, 4, 4.5, 2, False),
            BottleneckBlock(24, 24, 3, 4, 3.6, 1, False),

            BottleneckBlock(24, 40, 5, 4, 4, 2, True),
            BottleneckBlock(40, 40, 5, 4, 6, 1, True),
            BottleneckBlock(40, 40, 5, 4, 6, 1, True),

            BottleneckBlock(40, 48, 5, 4, 3, 1, True),

            BottleneckBlock(48, 48, 5, 4, 3, 1, True),
            BottleneckBlock(48, 96, 5, 4, 6, 2, True),

            nn.Conv2d(96, 192, kernel_size=1, stride=1),
            nn.BatchNorm2d(192),
            nn.ReLU(),

            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Conv2d(192, 384, kernel_size=1, stride=1),
            nn.ReLU(),
            nn.Conv2d(384, 384, kernel_size=1, stride=1),
        )

        self.linear = nn.Linear(384, 100)

    def forward(self, x):
        x = self.layers(x)
        x = x.view(x.size(0), -1)  # Flatten
        x = self.linear(x)
        return x

# %%
torch.backends.cudnn.benchmark = True
torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.allow_tf32 = True
torch.set_float32_matmul_precision('high')

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

if torch.cuda.is_available():
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
    torch.cuda.empty_cache()

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # Mild to avoid over-distortion
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5071, 0.4865, 0.4409], std=[0.2673, 0.2564, 0.2761]),
    transforms.RandomErasing(p=0.5)  # Apply after normalization for consistency
])

test_transform = transforms.Compose([
    transforms.ToTensor(), # Moved ToTensor before Normalize (good practice)
    transforms.Normalize(mean=[0.5071, 0.4867, 0.4408], std=[0.2675, 0.2565, 0.2761])
])

# Load raw datasets
cifar_train_raw = datasets.CIFAR100(root="./data", train=True, download=True, transform=None)

train_size = int(0.9 * len(cifar_train_raw))  # 48,000

train_indices = list(range(0, train_size))
val_indices = list(range(train_size, len(cifar_train_raw)))

# Create datasets with appropriate transforms
cifar_train = Subset(
    datasets.CIFAR100(root="./data", train=True, transform=train_transform),
    train_indices
)
cifar_val = Subset(
    datasets.CIFAR100(root="./data", train=True, transform=test_transform),
    val_indices
)
# Use original test set (10,000 samples) - close to 10% of 60,000
cifar_test = datasets.CIFAR100(root="./data", train=False, transform=test_transform)

train_loader = DataLoader(
    cifar_train,  # Use directly
    batch_size=1024,
    shuffle=True,
    num_workers=2,
    pin_memory=True,
    persistent_workers=True,
    prefetch_factor=6
)

val_loader = DataLoader(
    cifar_val,  # Use directly
    batch_size=1024,
    shuffle=False,
    num_workers=2,
    pin_memory=True,
    persistent_workers=True,
    prefetch_factor=6
)

test_loader = DataLoader(
    cifar_test,
    batch_size=1024,
    shuffle=False,
    num_workers=2,
    pin_memory=True,
    persistent_workers=True,
    prefetch_factor=6
)

num_classes = 100

model = MobileNetV3().to(device)

num_epochs = 40
loss_function = nn.CrossEntropyLoss(label_smoothing=0.1)
base_lr = 4e-3

batch_scale = 1024 / 256  # 4x larger batches
scaled_lr = base_lr * batch_scale**0.5  # Square root scaling

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=3e-3,  # Keep this for now, let OneCycleLR handle it
    weight_decay=5e-4
)

scheduler = torch.optim.lr_scheduler.OneCycleLR(
    optimizer,
    max_lr=5e-3,                # Slightly lower peak LR for stability
    epochs=num_epochs,          # Keep 45 epochs
    steps_per_epoch=len(train_loader),
    pct_start=0.4,              # Increase warmup to 40% (18 epochs)
    anneal_strategy='cos',
    div_factor=12.0,            # Start LR = 5e-3 / 12 = 4.2e-4
    final_div_factor=400.0      # Final LR = 5e-3 / 400 = 1.25e-5
)

best_val_loss = float('inf')

for epoch in range(num_epochs):
    print(f'Starting Epoch {epoch+1}')
    model.train()

    current_loss = 0.0
    num_batches = 0

    for i, data in enumerate(train_loader):
        inputs, targets = data
        inputs, targets = inputs.to(device), targets.to(device)
            
        outputs = model(inputs)
        loss = loss_function(outputs, targets)
        loss.backward()

        optimizer.step()
        optimizer.zero_grad(set_to_none=True)
        scheduler.step()

        current_loss += loss.item()
        num_batches += 1

        if i % 50 == 0:
            print(f'Batch {i}/{len(train_loader)}, Loss: {loss.item():.4f}')


    avg_train_loss = current_loss / num_batches
    print(f'Epoch {epoch+1} finished')
    print(f'Training - Loss: {avg_train_loss:.4f}')

    if (epoch + 1) % 2 == 0:
        model.eval()
        val_loss = 0.0
        val_batches = 0

        print(f'Epoch {epoch+1} finished')
        print(f'average training loss is {avg_train_loss:.4f}')

        with torch.no_grad():
            for val_data in val_loader:
                val_inputs, val_targets = val_data
                val_inputs, val_targets = val_inputs.to(device), val_targets.to(device)  # Convert inputs to FP16

                val_outputs = model(val_inputs)
                val_batch_loss = loss_function(val_outputs, val_targets)

                val_loss += val_batch_loss.item()
                val_batches += 1


        avg_val_loss = val_loss / val_batches

        print(f'Epoch {epoch+1} finished')
        print(f'Training - Loss: {avg_train_loss:.4f}')
        print(f'Validation - Loss: {avg_val_loss:.4f}')

if torch.cuda.is_available():
    torch.cuda.empty_cache()
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/backends/__init__.py:46: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   self.setter(val)
# Using device: cuda
# GPU Memory: 15.8 GB
# 100%|██████████| 169M/169M [00:13<00:00, 12.3MB/s]
# Starting Epoch 1
# Batch 0/44, Loss: 4.6063
# Epoch 1 finished
# Training - Loss: 4.6017
# Starting Epoch 2
# Batch 0/44, Loss: 4.5988
# Epoch 2 finished
# Training - Loss: 4.5900
# Epoch 2 finished
# average training loss is 4.5900
# Epoch 2 finished
# Training - Loss: 4.5900
# Validation - Loss: 6.9904
# Starting Epoch 3
# Batch 0/44, Loss: 4.5864
# Epoch 3 finished
# Training - Loss: 4.5727
# Starting Epoch 4
# Batch 0/44, Loss: 4.5505
# Epoch 4 finished
# Training - Loss: 4.5336
# Epoch 4 finished
# average training loss is 4.5336
# Epoch 4 finished
# Training - Loss: 4.5336
# Validation - Loss: 5.1449
# Starting Epoch 5
# Batch 0/44, Loss: 4.5298
# Epoch 5 finished
# Training - Loss: 4.4377
# Starting Epoch 6
# Batch 0/44, Loss: 4.3333
# Epoch 6 finished
# Training - Loss: 4.2927
# Epoch 6 finished
# average training loss is 4.2927
# Epoch 6 finished
# Training - Loss: 4.2927
# Validation - Loss: 4.2809
# Starting Epoch 7
# Batch 0/44, Loss: 4.2580
# Epoch 7 finished
# Training - Loss: 4.2189
# Starting Epoch 8
# Batch 0/44, Loss: 4.1968
# Epoch 8 finished
# Training - Loss: 4.1544
# Epoch 8 finished
# average training loss is 4.1544
# Epoch 8 finished
# Training - Loss: 4.1544
# Validation - Loss: 4.1850
# Starting Epoch 9
# Batch 0/44, Loss: 4.0851
# Epoch 9 finished
# Training - Loss: 4.0909
# Starting Epoch 10
# Batch 0/44, Loss: 4.1163
# Epoch 10 finished
# Training - Loss: 4.0423
# Epoch 10 finished
# average training loss is 4.0423
# Epoch 10 finished
# Training - Loss: 4.0423
# Validation - Loss: 4.0892
# Starting Epoch 11
# Batch 0/44, Loss: 4.0245
# Epoch 11 finished
# Training - Loss: 3.9938
# Starting Epoch 12
# Batch 0/44, Loss: 3.9385
# Epoch 12 finished
# Training - Loss: 3.9614
# Epoch 12 finished
# average training loss is 3.9614
# Epoch 12 finished
# Training - Loss: 3.9614
# Validation - Loss: 3.9361
# Starting Epoch 13
# Batch 0/44, Loss: 3.9597
# Epoch 13 finished
# Training - Loss: 3.9180
# Starting Epoch 14
# Batch 0/44, Loss: 3.9227
# Epoch 14 finished
# Training - Loss: 3.8801
# Epoch 14 finished
# average training loss is 3.8801
# Epoch 14 finished
# Training - Loss: 3.8801
# Validation - Loss: 3.7957
# Starting Epoch 15
# Batch 0/44, Loss: 3.8314
# Epoch 15 finished
# Training - Loss: 3.8420
# Starting Epoch 16
# Batch 0/44, Loss: 3.7990
# Epoch 16 finished
# Training - Loss: 3.7988
# Epoch 16 finished
# average training loss is 3.7988
# Epoch 16 finished
# Training - Loss: 3.7988
# Validation - Loss: 3.7208
# Starting Epoch 17
# Batch 0/44, Loss: 3.7866
# Epoch 17 finished
# Training - Loss: 3.7378
# Starting Epoch 18
# Batch 0/44, Loss: 3.6707
# Epoch 18 finished
# Training - Loss: 3.6936
# Epoch 18 finished
# average training loss is 3.6936
# Epoch 18 finished
# Training - Loss: 3.6936
# Validation - Loss: 3.7489
# Starting Epoch 19
# Batch 0/44, Loss: 3.6987
# Epoch 19 finished
# Training - Loss: 3.6530
# Starting Epoch 20
# Batch 0/44, Loss: 3.6112
# Epoch 20 finished
# Training - Loss: 3.6053
# Epoch 20 finished
# average training loss is 3.6053
# Epoch 20 finished
# Training - Loss: 3.6053
# Validation - Loss: 3.5426
# Starting Epoch 21
# Batch 0/44, Loss: 3.5926
# Epoch 21 finished
# Training - Loss: 3.5583
# Starting Epoch 22
# Batch 0/44, Loss: 3.4941
# Epoch 22 finished
# Training - Loss: 3.5322
# Epoch 22 finished
# average training loss is 3.5322
# Epoch 22 finished
# Training - Loss: 3.5322
# Validation - Loss: 3.4485
# Starting Epoch 23
# Batch 0/44, Loss: 3.4697
# Epoch 23 finished
# Training - Loss: 3.4807
# Starting Epoch 24
# Batch 0/44, Loss: 3.4579
# Epoch 24 finished
# Training - Loss: 3.4484
# Epoch 24 finished
# average training loss is 3.4484
# Epoch 24 finished
# Training - Loss: 3.4484
# Validation - Loss: 3.3724
# Starting Epoch 25
# Batch 0/44, Loss: 3.3373
# Epoch 25 finished
# Training - Loss: 3.4159
# Starting Epoch 26
# Batch 0/44, Loss: 3.3365
# Epoch 26 finished
# Training - Loss: 3.3791
# Epoch 26 finished
# average training loss is 3.3791
# Epoch 26 finished
# Training - Loss: 3.3791
# Validation - Loss: 3.3124
# Starting Epoch 27
# Batch 0/44, Loss: 3.2866
# Epoch 27 finished
# Training - Loss: 3.3402
# Starting Epoch 28
# Batch 0/44, Loss: 3.2211
# Epoch 28 finished
# Training - Loss: 3.3016
# Epoch 28 finished
# average training loss is 3.3016
# Epoch 28 finished
# Training - Loss: 3.3016
# Validation - Loss: 3.2254
# Starting Epoch 29
# Batch 0/44, Loss: 3.1823
# Epoch 29 finished
# Training - Loss: 3.2782
# Starting Epoch 30
# Batch 0/44, Loss: 3.2353
# Epoch 30 finished
# Training - Loss: 3.2492
# Epoch 30 finished
# average training loss is 3.2492
# Epoch 30 finished
# Training - Loss: 3.2492
# Validation - Loss: 3.1848
# Starting Epoch 31
# Batch 0/44, Loss: 3.2296
# Epoch 31 finished
# Training - Loss: 3.2162
# Starting Epoch 32
# Batch 0/44, Loss: 3.1564
# Epoch 32 finished
# Training - Loss: 3.1901
# Epoch 32 finished
# average training loss is 3.1901
# Epoch 32 finished
# Training - Loss: 3.1901
# Validation - Loss: 3.1454
# Starting Epoch 33
# Batch 0/44, Loss: 3.1902
# Epoch 33 finished
# Training - Loss: 3.1711
# Starting Epoch 34
# Batch 0/44, Loss: 3.1317
# Epoch 34 finished
# Training - Loss: 3.1492
# Epoch 34 finished
# average training loss is 3.1492
# Epoch 34 finished
# Training - Loss: 3.1492
# Validation - Loss: 3.1196
# Starting Epoch 35
# Batch 0/44, Loss: 3.0784
# Epoch 35 finished
# Training - Loss: 3.1201
# Starting Epoch 36
# Batch 0/44, Loss: 3.0255
# Epoch 36 finished
# Training - Loss: 3.1104
# Epoch 36 finished
# average training loss is 3.1104
# Epoch 36 finished
# Training - Loss: 3.1104
# Validation - Loss: 3.0973
# Starting Epoch 37
# Batch 0/44, Loss: 3.0573
# Epoch 37 finished
# Training - Loss: 3.1038
# Starting Epoch 38
# Batch 0/44, Loss: 3.1164
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3301500819.py in <cell line: 0>()
#     112     num_batches = 0
#     113
# --> 114     for i, data in enumerate(train_loader):
#     115         inputs, targets = data
#     116         inputs, targets = inputs.to(device), targets.to(device)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     730                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731                 self._reset()  # type: ignore[call-arg]
# --> 732             data = self._next_data()
#     733             self._num_yielded += 1
#     734             if (
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1480
#    1481             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1482             idx, data = self._get_data()
#    1483             self._tasks_outstanding -= 1
#    1484             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1432         elif self._pin_memory:
#    1433             while self._pin_memory_thread.is_alive():
# -> 1434                 success, data = self._try_get_data()
#    1435                 if success:
#    1436                     return data
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1273         #   (bool: whether successfully get data, any: data if successful else None)
#    1274         try:
# -> 1275             data = self._data_queue.get(timeout=timeout)
#    1276             return (True, data)
#    1277         except Exception as e:
#
# /usr/lib/python3.12/queue.py in get(self, block, timeout)
#     178                     if remaining <= 0.0:
#     179                         raise Empty
# --> 180                     self.not_empty.wait(remaining)
#     181             item = self._get()
#     182             self.not_full.notify()
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     357             else:
#     358                 if timeout > 0:
# --> 359                     gotit = waiter.acquire(True, timeout)
#     360                 else:
#     361                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
def evaluate_test_set(model):
    model.eval()
    correct = 0
    total = 0
    
    print("Starting evaluation...")
    
    with torch.no_grad():
        for data in test_loader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            
            # Use autocast for consistency if you trained with it
            outputs = model(images)
            
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    print(f'Accuracy of the network on the test images: {accuracy:.2f}%')
    return accuracy

print("\n=== Running standard evaluation ===")
standard_accuracy = evaluate_test_set(model)   
print(f'Standard Test Accuracy: {standard_accuracy:.4f} ({standard_accuracy*100:.2f}%)')
